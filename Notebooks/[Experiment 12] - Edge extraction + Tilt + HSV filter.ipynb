# %% [markdown]
# In this experiment:
# 1. Apply an HSV filter where we reduce Value of all images to 0
# 2. Apply Li threshold on value-filtered images
# 3. Extract edge
# 4. Tilt edge horizontally

# %%
import skimage
from skimage import measure
import matplotlib.pyplot as plt
from skimage import data, io, color
from skimage.filters import threshold_li
from skimage.filters import try_all_threshold
from skimage.color import rgb2hsv
import numpy as np
from matplotlib import path
from matplotlib.path import Path
import matplotlib.patches as patches
import math

# %%
# Function to apply a Value filter to input image
# Input: Path to image
# Output: image converted to 2-dimensional array, with Value reduced to 0, Hue and Saturation unchanged
def hsv_value_filter(imgpath):
    rgb_img = skimage.io.imread(imgpath)
    hsv_img = rgb2hsv(rgb_img)
    value_img = hsv_img[:, :, 2]
    return value_img


# Function to find contour line from grayscale image
# Input: Grayscale image (2-dimensional array with values from 0-1)
# output: Contour line
def tail_contour_li_threshold_grayscale_input(tail_img_gray):
    #tail_img_gray = color.rgb2gray(tail_img)  
    mask_threshold = threshold_li(tail_img_gray)
    tail_img_mask = tail_img_gray < mask_threshold
    contours = measure.find_contours(tail_img_mask, 0.9) 
    # Find the largest contour in the list of contours
    contours.sort(key=len,reverse=True)
    largest_contour = contours[0]
    return largest_contour

# https://stackoverflow.com/questions/34372480/rotate-point-about-another-point-in-degrees-python
# Function to rotate a set of points around an origin by a predefined degrees
# Input: set of points, for example a contour line; origin of rotation; rotation angle in degree
# Output: the same set of points rotated
def rotate(p, origin=(0, 0), degrees=0):
    angle = np.deg2rad(degrees)
    R = np.array([[np.cos(angle), -np.sin(angle)],
                  [np.sin(angle),  np.cos(angle)]])
    o = np.atleast_2d(origin)
    p = np.atleast_2d(p)
    return np.squeeze((R @ (p.T-o.T) + o.T).T)

# Function to extract edge line from a given contour. 
# Edge line is tilted so that the straight line connecting left-right tips is parallel with x axis
# Input: contour line
# Ourput: edge line, tilted horizontally
def extract_edge_tilt(contour):
    # Move contour to line towards root (0,0)
    contour[:,0] -= contour[:,0].min()
    contour[:,1] -= contour[:,1].min()

    # Get middle y point of contour line
    middle_y = (contour[:,0].max() - contour[:,0].min())/2

    # FIND NOTCH POINT
    # Get 25% and 75% on x as left and right boundaries to find notch point
    left_bound = contour[:,1].max() * 0.25
    right_bound = contour[:,1].max() * 0.75

    # Cut the area containing notch point by middle_y, left and right boundaries
    c_notch = contour[ (contour[:,0] < middle_y) & (contour[:,1] > left_bound) & (contour[:,1] < right_bound)]

    # If there is no point in the notch area => bad contour line, stops finding edge & returns bottom half of the contour image
    if (len(c_notch) == 0):
        return contour[(contour[:,0] < middle_y)]

    # Find notch points == points that have the highest y in the notch area
    c_notch_y = c_notch[:,0].max()
    c_notch_points = c_notch[c_notch[:,0] == c_notch_y]

    notch_point = c_notch_points[0]

    # FIND LEFT-RIGHT TIPS OF THE FLUKE
    # Cut the bottom half of the tail
    c_bottom = contour[ (contour[:,0] < middle_y)]
    # Find the left tip
    left_tip_x = c_bottom[:,1].min()
    left_tips = c_bottom[c_bottom[:,1] == left_tip_x]
    left_tip = left_tips[0] # if there are several points at min_x
    # Find the right tip
    right_tip_x = c_bottom[:,1].max()
    right_tips = c_bottom[c_bottom[:,1] == right_tip_x]
    right_tip = right_tips[-1] # if there are several points at max_x
    
    # CREATE A PATH OBJECT THAT BOUNDS THE FLUKE
    # The path is limited by 5 points: bottom_left,left_tip, notch_point, right_tip,bottom_right
    bottom_left = np.array([0,left_tip[1]])
    bottom_right = np.array([0,right_tip[1]])
    verts = [bottom_left,left_tip, notch_point, right_tip,bottom_right,bottom_left]
    codes = [
        Path.MOVETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.LINETO,
        Path.CLOSEPOLY,
    ]
    edge_path = Path(verts, codes)
    
    # Extract the edge from bottom half of the image using the path as a mask
    c_edge = c_bottom[edge_path.contains_points(c_bottom)]
    
    # Identify the tilt angle
    diff = right_tip - left_tip
    tilt_angle = np.rad2deg(math.atan(diff[0]/diff[1]))
    
    # Identify rotate center - midpoint of left and right tips
    rotate_center = ((left_tip[0]+right_tip[0])/2,(left_tip[1]+right_tip[1])/2)
        
    # Rotate the edge to balance horizontally around the rotate center
    c_edge_tilted = rotate(c_edge, origin=rotate_center, degrees=tilt_angle)
    return c_edge_tilted

# %% [markdown]
# ## Test with one image

# %%
#input_img = '../experiments/contrast/PM-WWA-20110829-037.jpg'
#input_img = '../data/train/2352/PM-WWA-20050612-006.jpg'
#input_img = '../experiments/contrast/equalTail.jpg'
input_img = '../experiments/rotate/tail+10.jpg'
tail_img = hsv_value_filter(input_img)
c = tail_contour_li_threshold_grayscale_input(tail_img)
edge = extract_edge_tilt(c)

# %%
fig = plt.figure(figsize=(8,3)) 
plt.plot(edge[:, 1], edge[:, 0],  linewidth=1, color = 'black')

# %% [markdown]
# ## Save edge images

# %% [markdown]
# ### Function to extract fluke edge from tail images, tilt the edge, then store edge images to output path

# %%
def save_edge(source_img_path, output_path):
    # Load the image, convert to hsv and reduce Value to 0
    tail_img_filtered = hsv_value_filter(source_img_path)
          
    c = tail_contour_li_threshold_grayscale_input(tail_img_filtered)
    edge = extract_edge_tilt(c)
    
    # Save image to output_path
    # fig = plt.figure(figsize=(8,3)) # Experiment 6.0: scaled y; fixed size for all output image
    
    fig = plt.figure(figsize=(8,3))  # Experiment 6.1: No scaling output images
    #fig = plt.figure(figsize=(16,6))  # Experiment 6.2: No scaling output images; increased output img size
    plt.gca().set_aspect('equal', adjustable='box') # ensure 2 axes are on the same scale
    
    # Experiment 6.3: Resize output image closest to the size fed into MobileNet (224x224)
    #my_dpi=96 # This combination returns output images with size (224x219), best try
    #fig = plt.figure(figsize=(2.76, 2.76), dpi=my_dpi)
    #plt.axis('equal')
    
    plt.plot(edge[:, 1], edge[:, 0],  linewidth=1, color = 'black')  
    plt.axis('off')
    plt.savefig(output_path, cmap = "gray", bbox_inches='tight') # Experiments 6.0, 6.1, 6.2
    #plt.savefig(output_path, cmap = "gray", bbox_inches='tight', dpi=my_dpi) # Experiment 6.3
    plt.close(fig) # do not plot the image to screen

# %% [markdown]
# ### Store test-val files

# %%
import os
testval_path = "../data/test_val/"
testval_contour_path = "../experiments/12. contour_edge_Li_tilt_noscaling_hsv-filter/test-val/"

images = os.listdir(testval_path)

img_count = len(images)
i = 0

for img in images:
    in_file = testval_path + img
    out_file = testval_contour_path + img
    save_edge(in_file, out_file)
    
    #progress tracking
    i += 1
    if (i%10 == 0):
        print("processed {}/{} images ({}%)".format(i,img_count,round(i/img_count*100,2)))
# Out:
# processed 10/808 images (1.24%)
# processed 20/808 images (2.48%)
# processed 30/808 images (3.71%)
# processed 40/808 images (4.95%)
# processed 50/808 images (6.19%)
# processed 60/808 images (7.43%)
# processed 70/808 images (8.66%)
# processed 80/808 images (9.9%)
# processed 90/808 images (11.14%)
# processed 100/808 images (12.38%)
# processed 110/808 images (13.61%)
# processed 120/808 images (14.85%)
# processed 130/808 images (16.09%)
# processed 140/808 images (17.33%)
# processed 150/808 images (18.56%)
# processed 160/808 images (19.8%)
# processed 170/808 images (21.04%)
# processed 180/808 images (22.28%)
# processed 190/808 images (23.51%)
# processed 200/808 images (24.75%)
# processed 210/808 images (25.99%)
# processed 220/808 images (27.23%)
# processed 230/808 images (28.47%)
# processed 240/808 images (29.7%)
# processed 250/808 images (30.94%)
# processed 260/808 images (32.18%)
# processed 270/808 images (33.42%)
# processed 280/808 images (34.65%)
# processed 290/808 images (35.89%)
# processed 300/808 images (37.13%)
# processed 310/808 images (38.37%)
# processed 320/808 images (39.6%)
# processed 330/808 images (40.84%)
# processed 340/808 images (42.08%)
# processed 350/808 images (43.32%)
# processed 360/808 images (44.55%)
# processed 370/808 images (45.79%)
# processed 380/808 images (47.03%)
# processed 390/808 images (48.27%)
# processed 400/808 images (49.5%)
# processed 410/808 images (50.74%)
# processed 420/808 images (51.98%)
# processed 430/808 images (53.22%)
# processed 440/808 images (54.46%)
# processed 450/808 images (55.69%)
# processed 460/808 images (56.93%)
# processed 470/808 images (58.17%)
# processed 480/808 images (59.41%)
# processed 490/808 images (60.64%)
# processed 500/808 images (61.88%)
# processed 510/808 images (63.12%)
# processed 520/808 images (64.36%)
# processed 530/808 images (65.59%)
# processed 540/808 images (66.83%)
# processed 550/808 images (68.07%)
# processed 560/808 images (69.31%)
# processed 570/808 images (70.54%)
# processed 580/808 images (71.78%)
# processed 590/808 images (73.02%)
# processed 600/808 images (74.26%)
# processed 610/808 images (75.5%)
# processed 620/808 images (76.73%)
# processed 630/808 images (77.97%)
# processed 640/808 images (79.21%)
# processed 650/808 images (80.45%)
# processed 660/808 images (81.68%)
# processed 670/808 images (82.92%)
# processed 680/808 images (84.16%)
# processed 690/808 images (85.4%)
# processed 700/808 images (86.63%)
# processed 710/808 images (87.87%)
# processed 720/808 images (89.11%)
# processed 730/808 images (90.35%)
# processed 740/808 images (91.58%)
# processed 750/808 images (92.82%)
# processed 760/808 images (94.06%)
# processed 770/808 images (95.3%)
# processed 780/808 images (96.53%)
# processed 790/808 images (97.77%)
# processed 800/808 images (99.01%)

# %% [markdown]
# ### Store train files (ignore -1 folder)

# %%
import os
train_path = "../data/train/"
train_contour_path = "../experiments/12. contour_edge_Li_tilt_noscaling_hsv-filter/train/"

subfolders = os.listdir(train_path)

train_file_count = 4539 - 577 # We know in advance the number of training images, in whih 577 images belong to class -1
i=0

for sf in subfolders:
    #Skip folder -1 
    if (sf == '-1'):
        continue 
    
    # Create sub-folder for train contours if not exist
    train_contour_path_subfolder = train_contour_path + sf
    if not os.path.exists(train_contour_path_subfolder):
        os.makedirs(train_contour_path_subfolder)  
    
    # Get list of images in each subfolder
    images = os.listdir(train_path + sf)
    # Find contour for each image
    for img in images:
        in_file = train_path + sf + "/" + img
        out_file = train_contour_path + sf + "/" + img
        save_edge(in_file, out_file)
        #progress tracking
        i += 1
        if (i%10 == 0):
            print("processed {}/{} images ({}%)".format(i,train_file_count,round(i/train_file_count*100,2)))
# Out:
# processed 10/3962 images (0.25%)
# processed 20/3962 images (0.5%)
# processed 30/3962 images (0.76%)
# processed 40/3962 images (1.01%)
# processed 50/3962 images (1.26%)
# processed 60/3962 images (1.51%)
# processed 70/3962 images (1.77%)
# processed 80/3962 images (2.02%)
# processed 90/3962 images (2.27%)
# processed 100/3962 images (2.52%)
# processed 110/3962 images (2.78%)
# processed 120/3962 images (3.03%)
# processed 130/3962 images (3.28%)
# processed 140/3962 images (3.53%)
# processed 150/3962 images (3.79%)
# processed 160/3962 images (4.04%)
# processed 170/3962 images (4.29%)
# processed 180/3962 images (4.54%)
# processed 190/3962 images (4.8%)
# processed 200/3962 images (5.05%)
# processed 210/3962 images (5.3%)
# processed 220/3962 images (5.55%)
# processed 230/3962 images (5.81%)
# processed 240/3962 images (6.06%)
# processed 250/3962 images (6.31%)
# processed 260/3962 images (6.56%)
# processed 270/3962 images (6.81%)
# processed 280/3962 images (7.07%)
# processed 290/3962 images (7.32%)
# processed 300/3962 images (7.57%)
# processed 310/3962 images (7.82%)
# processed 320/3962 images (8.08%)
# processed 330/3962 images (8.33%)
# processed 340/3962 images (8.58%)
# processed 350/3962 images (8.83%)
# processed 360/3962 images (9.09%)
# processed 370/3962 images (9.34%)
# processed 380/3962 images (9.59%)
# processed 390/3962 images (9.84%)
# processed 400/3962 images (10.1%)
# processed 410/3962 images (10.35%)
# processed 420/3962 images (10.6%)
# processed 430/3962 images (10.85%)
# processed 440/3962 images (11.11%)
# processed 450/3962 images (11.36%)
# processed 460/3962 images (11.61%)
# processed 470/3962 images (11.86%)
# processed 480/3962 images (12.12%)
# processed 490/3962 images (12.37%)
# processed 500/3962 images (12.62%)
# processed 510/3962 images (12.87%)
# processed 520/3962 images (13.12%)
# processed 530/3962 images (13.38%)
# processed 540/3962 images (13.63%)
# processed 550/3962 images (13.88%)
# processed 560/3962 images (14.13%)
# processed 570/3962 images (14.39%)
# processed 580/3962 images (14.64%)
# processed 590/3962 images (14.89%)
# processed 600/3962 images (15.14%)
# processed 610/3962 images (15.4%)
# processed 620/3962 images (15.65%)
# processed 630/3962 images (15.9%)
# processed 640/3962 images (16.15%)
# processed 650/3962 images (16.41%)
# processed 660/3962 images (16.66%)
# processed 670/3962 images (16.91%)
# processed 680/3962 images (17.16%)
# processed 690/3962 images (17.42%)
# processed 700/3962 images (17.67%)
# processed 710/3962 images (17.92%)
# processed 720/3962 images (18.17%)
# processed 730/3962 images (18.43%)
# processed 740/3962 images (18.68%)
# processed 750/3962 images (18.93%)
# processed 760/3962 images (19.18%)
# processed 770/3962 images (19.43%)
# processed 780/3962 images (19.69%)
# processed 790/3962 images (19.94%)
# processed 800/3962 images (20.19%)
# processed 810/3962 images (20.44%)
# processed 820/3962 images (20.7%)
# processed 830/3962 images (20.95%)
# processed 840/3962 images (21.2%)
# processed 850/3962 images (21.45%)
# processed 860/3962 images (21.71%)
# processed 870/3962 images (21.96%)
# processed 880/3962 images (22.21%)
# processed 890/3962 images (22.46%)
# processed 900/3962 images (22.72%)
# processed 910/3962 images (22.97%)
# processed 920/3962 images (23.22%)
# processed 930/3962 images (23.47%)
# processed 940/3962 images (23.73%)
# processed 950/3962 images (23.98%)
# processed 960/3962 images (24.23%)
# processed 970/3962 images (24.48%)
# processed 980/3962 images (24.73%)
# processed 990/3962 images (24.99%)
# processed 1000/3962 images (25.24%)
# processed 1010/3962 images (25.49%)
# processed 1020/3962 images (25.74%)
# processed 1030/3962 images (26.0%)
# processed 1040/3962 images (26.25%)
# processed 1050/3962 images (26.5%)
# processed 1060/3962 images (26.75%)
# processed 1070/3962 images (27.01%)
# processed 1080/3962 images (27.26%)
# processed 1090/3962 images (27.51%)
# processed 1100/3962 images (27.76%)
# processed 1110/3962 images (28.02%)
# processed 1120/3962 images (28.27%)
# processed 1130/3962 images (28.52%)
# processed 1140/3962 images (28.77%)
# processed 1150/3962 images (29.03%)
# processed 1160/3962 images (29.28%)
# processed 1170/3962 images (29.53%)
# processed 1180/3962 images (29.78%)
# processed 1190/3962 images (30.04%)
# processed 1200/3962 images (30.29%)
# processed 1210/3962 images (30.54%)
# processed 1220/3962 images (30.79%)
# processed 1230/3962 images (31.04%)
# processed 1240/3962 images (31.3%)
# processed 1250/3962 images (31.55%)
# processed 1260/3962 images (31.8%)
# processed 1270/3962 images (32.05%)
# processed 1280/3962 images (32.31%)
# processed 1290/3962 images (32.56%)
# processed 1300/3962 images (32.81%)
# processed 1310/3962 images (33.06%)
# processed 1320/3962 images (33.32%)
# processed 1330/3962 images (33.57%)
# processed 1340/3962 images (33.82%)
# processed 1350/3962 images (34.07%)
# processed 1360/3962 images (34.33%)
# processed 1370/3962 images (34.58%)
# processed 1380/3962 images (34.83%)
# processed 1390/3962 images (35.08%)
# processed 1400/3962 images (35.34%)
# processed 1410/3962 images (35.59%)
# processed 1420/3962 images (35.84%)
# processed 1430/3962 images (36.09%)
# processed 1440/3962 images (36.35%)
# processed 1450/3962 images (36.6%)
# processed 1460/3962 images (36.85%)
# processed 1470/3962 images (37.1%)
# processed 1480/3962 images (37.35%)
# processed 1490/3962 images (37.61%)
# processed 1500/3962 images (37.86%)
# processed 1510/3962 images (38.11%)
# processed 1520/3962 images (38.36%)
# processed 1530/3962 images (38.62%)
# processed 1540/3962 images (38.87%)
# processed 1550/3962 images (39.12%)
# processed 1560/3962 images (39.37%)
# processed 1570/3962 images (39.63%)
# processed 1580/3962 images (39.88%)
# processed 1590/3962 images (40.13%)
# processed 1600/3962 images (40.38%)
# processed 1610/3962 images (40.64%)
# processed 1620/3962 images (40.89%)
# processed 1630/3962 images (41.14%)
# processed 1640/3962 images (41.39%)
# processed 1650/3962 images (41.65%)
# processed 1660/3962 images (41.9%)
# processed 1670/3962 images (42.15%)
# processed 1680/3962 images (42.4%)
# processed 1690/3962 images (42.66%)
# processed 1700/3962 images (42.91%)
# processed 1710/3962 images (43.16%)
# processed 1720/3962 images (43.41%)
# processed 1730/3962 images (43.66%)
# processed 1740/3962 images (43.92%)
# processed 1750/3962 images (44.17%)
# processed 1760/3962 images (44.42%)
# processed 1770/3962 images (44.67%)
# processed 1780/3962 images (44.93%)
# processed 1790/3962 images (45.18%)
# processed 1800/3962 images (45.43%)
# processed 1810/3962 images (45.68%)
# processed 1820/3962 images (45.94%)
# processed 1830/3962 images (46.19%)
# processed 1840/3962 images (46.44%)
# processed 1850/3962 images (46.69%)
# processed 1860/3962 images (46.95%)
# processed 1870/3962 images (47.2%)
# processed 1880/3962 images (47.45%)
# processed 1890/3962 images (47.7%)
# processed 1900/3962 images (47.96%)
# processed 1910/3962 images (48.21%)
# processed 1920/3962 images (48.46%)
# processed 1930/3962 images (48.71%)
# processed 1940/3962 images (48.97%)
# processed 1950/3962 images (49.22%)
# processed 1960/3962 images (49.47%)
# processed 1970/3962 images (49.72%)
# processed 1980/3962 images (49.97%)
# processed 1990/3962 images (50.23%)
# processed 2000/3962 images (50.48%)
# processed 2010/3962 images (50.73%)
# processed 2020/3962 images (50.98%)
# processed 2030/3962 images (51.24%)
# processed 2040/3962 images (51.49%)
# processed 2050/3962 images (51.74%)
# processed 2060/3962 images (51.99%)
# processed 2070/3962 images (52.25%)
# processed 2080/3962 images (52.5%)
# processed 2090/3962 images (52.75%)
# processed 2100/3962 images (53.0%)
# processed 2110/3962 images (53.26%)
# processed 2120/3962 images (53.51%)
# processed 2130/3962 images (53.76%)
# processed 2140/3962 images (54.01%)
# processed 2150/3962 images (54.27%)
# processed 2160/3962 images (54.52%)
# processed 2170/3962 images (54.77%)
# processed 2180/3962 images (55.02%)
# processed 2190/3962 images (55.28%)
# processed 2200/3962 images (55.53%)
# processed 2210/3962 images (55.78%)
# processed 2220/3962 images (56.03%)
# processed 2230/3962 images (56.28%)
# processed 2240/3962 images (56.54%)
# processed 2250/3962 images (56.79%)
# processed 2260/3962 images (57.04%)
# processed 2270/3962 images (57.29%)
# processed 2280/3962 images (57.55%)
# processed 2290/3962 images (57.8%)
# processed 2300/3962 images (58.05%)
# processed 2310/3962 images (58.3%)
# processed 2320/3962 images (58.56%)
# processed 2330/3962 images (58.81%)
# processed 2340/3962 images (59.06%)
# processed 2350/3962 images (59.31%)
# processed 2360/3962 images (59.57%)
# processed 2370/3962 images (59.82%)
# processed 2380/3962 images (60.07%)
# processed 2390/3962 images (60.32%)
# processed 2400/3962 images (60.58%)
# processed 2410/3962 images (60.83%)
# processed 2420/3962 images (61.08%)
# processed 2430/3962 images (61.33%)
# processed 2440/3962 images (61.59%)
# processed 2450/3962 images (61.84%)
# processed 2460/3962 images (62.09%)
# processed 2470/3962 images (62.34%)
# processed 2480/3962 images (62.59%)
# processed 2490/3962 images (62.85%)
# processed 2500/3962 images (63.1%)
# processed 2510/3962 images (63.35%)
# processed 2520/3962 images (63.6%)
# processed 2530/3962 images (63.86%)
# processed 2540/3962 images (64.11%)
# processed 2550/3962 images (64.36%)
# processed 2560/3962 images (64.61%)
# processed 2570/3962 images (64.87%)
# processed 2580/3962 images (65.12%)
# processed 2590/3962 images (65.37%)
# processed 2600/3962 images (65.62%)
# processed 2610/3962 images (65.88%)
# processed 2620/3962 images (66.13%)
# processed 2630/3962 images (66.38%)
# processed 2640/3962 images (66.63%)
# processed 2650/3962 images (66.89%)
# processed 2660/3962 images (67.14%)
# processed 2670/3962 images (67.39%)
# processed 2680/3962 images (67.64%)
# processed 2690/3962 images (67.9%)
# processed 2700/3962 images (68.15%)
# processed 2710/3962 images (68.4%)
# processed 2720/3962 images (68.65%)
# processed 2730/3962 images (68.9%)
# processed 2740/3962 images (69.16%)
# processed 2750/3962 images (69.41%)
# processed 2760/3962 images (69.66%)
# processed 2770/3962 images (69.91%)
# processed 2780/3962 images (70.17%)
# processed 2790/3962 images (70.42%)
# processed 2800/3962 images (70.67%)
# processed 2810/3962 images (70.92%)
# processed 2820/3962 images (71.18%)
# processed 2830/3962 images (71.43%)
# processed 2840/3962 images (71.68%)
# processed 2850/3962 images (71.93%)
# processed 2860/3962 images (72.19%)
# processed 2870/3962 images (72.44%)
# processed 2880/3962 images (72.69%)
# processed 2890/3962 images (72.94%)
# processed 2900/3962 images (73.2%)
# processed 2910/3962 images (73.45%)
# processed 2920/3962 images (73.7%)
# processed 2930/3962 images (73.95%)
# processed 2940/3962 images (74.2%)
# processed 2950/3962 images (74.46%)
# processed 2960/3962 images (74.71%)
# processed 2970/3962 images (74.96%)
# processed 2980/3962 images (75.21%)
# processed 2990/3962 images (75.47%)
# processed 3000/3962 images (75.72%)
# processed 3010/3962 images (75.97%)
# processed 3020/3962 images (76.22%)
# processed 3030/3962 images (76.48%)
# processed 3040/3962 images (76.73%)
# processed 3050/3962 images (76.98%)
# processed 3060/3962 images (77.23%)
# processed 3070/3962 images (77.49%)
# processed 3080/3962 images (77.74%)
# processed 3090/3962 images (77.99%)
# processed 3100/3962 images (78.24%)
# processed 3110/3962 images (78.5%)
# processed 3120/3962 images (78.75%)
# processed 3130/3962 images (79.0%)
# processed 3140/3962 images (79.25%)
# processed 3150/3962 images (79.51%)
# processed 3160/3962 images (79.76%)
# processed 3170/3962 images (80.01%)
# processed 3180/3962 images (80.26%)
# processed 3190/3962 images (80.51%)
# processed 3200/3962 images (80.77%)
# processed 3210/3962 images (81.02%)
# processed 3220/3962 images (81.27%)
# processed 3230/3962 images (81.52%)
# processed 3240/3962 images (81.78%)
# processed 3250/3962 images (82.03%)
# processed 3260/3962 images (82.28%)
# processed 3270/3962 images (82.53%)
# processed 3280/3962 images (82.79%)
# processed 3290/3962 images (83.04%)
# processed 3300/3962 images (83.29%)
# processed 3310/3962 images (83.54%)
# processed 3320/3962 images (83.8%)
# processed 3330/3962 images (84.05%)
# processed 3340/3962 images (84.3%)
# processed 3350/3962 images (84.55%)
# processed 3360/3962 images (84.81%)
# processed 3370/3962 images (85.06%)
# processed 3380/3962 images (85.31%)
# processed 3390/3962 images (85.56%)
# processed 3400/3962 images (85.82%)
# processed 3410/3962 images (86.07%)
# processed 3420/3962 images (86.32%)
# processed 3430/3962 images (86.57%)
# processed 3440/3962 images (86.82%)
# processed 3450/3962 images (87.08%)
# processed 3460/3962 images (87.33%)
# processed 3470/3962 images (87.58%)
# processed 3480/3962 images (87.83%)
# processed 3490/3962 images (88.09%)
# processed 3500/3962 images (88.34%)
# processed 3510/3962 images (88.59%)
# processed 3520/3962 images (88.84%)
# processed 3530/3962 images (89.1%)
# processed 3540/3962 images (89.35%)
# processed 3550/3962 images (89.6%)
# processed 3560/3962 images (89.85%)
# processed 3570/3962 images (90.11%)
# processed 3580/3962 images (90.36%)
# processed 3590/3962 images (90.61%)
# processed 3600/3962 images (90.86%)
# processed 3610/3962 images (91.12%)
# processed 3620/3962 images (91.37%)
# processed 3630/3962 images (91.62%)
# processed 3640/3962 images (91.87%)
# processed 3650/3962 images (92.13%)
# processed 3660/3962 images (92.38%)
# processed 3670/3962 images (92.63%)
# processed 3680/3962 images (92.88%)
# processed 3690/3962 images (93.13%)
# processed 3700/3962 images (93.39%)
# processed 3710/3962 images (93.64%)
# processed 3720/3962 images (93.89%)
# processed 3730/3962 images (94.14%)
# processed 3740/3962 images (94.4%)
# processed 3750/3962 images (94.65%)
# processed 3760/3962 images (94.9%)
# processed 3770/3962 images (95.15%)
# processed 3780/3962 images (95.41%)
# processed 3790/3962 images (95.66%)
# processed 3800/3962 images (95.91%)
# processed 3810/3962 images (96.16%)
# processed 3820/3962 images (96.42%)
# processed 3830/3962 images (96.67%)
# processed 3840/3962 images (96.92%)
# processed 3850/3962 images (97.17%)
# processed 3860/3962 images (97.43%)
# processed 3870/3962 images (97.68%)
# processed 3880/3962 images (97.93%)
# processed 3890/3962 images (98.18%)
# processed 3900/3962 images (98.44%)
# processed 3910/3962 images (98.69%)
# processed 3920/3962 images (98.94%)
# processed 3930/3962 images (99.19%)
# processed 3940/3962 images (99.44%)
# processed 3950/3962 images (99.7%)
# processed 3960/3962 images (99.95%)

# %%
224/96
# Out:
# 2.3333333333333335

# %% [markdown]
# ## Edge line as image matrix instead of saving to disk

# %%
# %%time
input_img = '../experiments/rotate/tail+10.jpg'
tail_img_filtered = hsv_value_filter(input_img)
c = tail_contour_li_threshold_grayscale_input(tail_img_filtered)
edge = extract_edge_tilt(c)
# Out:
# Wall time: 155 ms

# %%
edge
# Out:
# array([[ 66.99653896,  -2.4110216 ],
#        [ 65.98376284,  -1.64012309],
#        [ 65.21286432,  -2.65289921],
#        ...,
#        [ 67.2434461 , 517.43699373],
#        [ 68.01434461, 518.44976985],
#        [ 68.1       , 518.56230054]])

# %%
fig = plt.figure(figsize=(8,3)) 
plt.plot(edge[:, 1], edge[:, 0],  linewidth=1, color = 'black')

# %%
# Function to convert contour/ edge curve to image in matrix representation
# Input: Contour / edge curve in form of points collection [[1.1,2.8],[3.6,4.3]]
# Output: Image of contour/edge curve in form of matrix representation
def curve_to_img_matrix(curve):
    curve_int = curve.astype(int)
    min_x = curve_int[:,1].min()
    min_y = curve_int[:,0].min()
    
    # Shift curve to x and y axis, make sure min_x = min_y = 0
    curve_int[:,1] -= min_x
    curve_int[:,0] -= min_y
    
    max_x = curve_int[:,1].max()
    max_y = curve_int[:,0].max()
    
    img_matrix = np.ones((max_y+1,max_x+1), dtype=int)
    for i,point in enumerate(curve_int):
        img_matrix[point[0],point[1]] = 0
        
    return img_matrix

# %%
# %time
edge_img = curve_to_img_matrix(edge)
edge_img.shape
# Out:
# Wall time: 0 ns
# (80, 521)

# %%
plt.figure(figsize=(12,12))   
plt.imshow(edge_img, cmap='gray');

# %%
import io
import cv2
def get_img_from_fig(contour, dpi=180):
    buf = io.BytesIO()
    fig = plt.figure(figsize=(8,3))  
    plt.gca().set_aspect('equal', adjustable='box') # ensure 2 axes are on the same scale
    plt.plot(contour[:, 1], contour[:, 0],  linewidth=1, color = 'black')  
    plt.axis('off')
    fig.savefig(buf, cmap = "gray", format='jpeg', bbox_inches='tight')
    plt.close(fig)
    
    buf.seek(0)
    img_arr = np.frombuffer(buf.getvalue(), dtype=np.uint8)
    buf.close()
    img = cv2.imdecode(img_arr, 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    return img_arr

# %%
fig = plt.figure(figsize=(8,3))  
plt.gca().set_aspect('equal', adjustable='box') # ensure 2 axes are on the same scale
plt.plot(edge[:, 1], edge[:, 0],  linewidth=1, color = 'black')  
plt.axis('off')
#plt.savefig(output_path, cmap = "gray", bbox_inches='tight')
#plt.close(fig) # do not plot the image to screen
# Out:
# (-29.024068805274926, 544.6378419321869, 16.01852804749525, 102.88676177469084)

# %%
edge_img=get_img_from_fig(edge)

# %%
plt.figure()   
plt.imshow(edge_img, interpolation='nearest');

# %%
edge_img
# Out:
# array([255, 216, 255, ...,  15, 255, 217], dtype=uint8)

# %% [markdown]
# ### Compare tf.image and skimage

# %%
import tensorflow as tf
BATCH_SIZE = 32
IMG_HEIGHT = IMG_WIDTH = 32

def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    #img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])  # Resize image to 224x224 pixels
    #img = preprocess_input(img)  # Do additional preprocessing that is required for MobileNet
    return img

# %%
input_img = '../experiments/rotate/tail+10.jpg'
img = load_image(input_img)

# %%
img
# Out:
# <tf.Tensor: id=10, shape=(449, 752, 3), dtype=uint8, numpy=
# array([[[136, 136, 134],
#         [134, 134, 132],
#         [134, 134, 132],
#         ...,
#         [117, 121, 124],
#         [116, 120, 123],
#         [114, 118, 121]],
#
#        [[138, 138, 136],
#         [137, 137, 135],
#         [139, 139, 137],
#         ...,
#         [115, 119, 122],
#         [113, 117, 120],
#         [111, 115, 118]],
#
#        [[141, 141, 141],
#         [142, 142, 142],
#         [144, 144, 144],
#         ...,
#         [112, 116, 117],
#         [108, 112, 113],
#         [106, 110, 111]],
#
#        ...,
#
#        [[119, 120, 115],
#         [117, 118, 113],
#         [114, 115, 110],
#         ...,
#         [ 65,  60,  57],
#         [ 62,  56,  56],
#         [ 62,  57,  54]],
#
#        [[122, 124, 119],
#         [122, 124, 119],
#         [122, 124, 119],
#         ...,
#         [ 82,  77,  74],
#         [ 80,  72,  70],
#         [ 77,  72,  69]],
#
#        [[122, 128, 124],
#         [123, 129, 125],
#         [125, 130, 126],
#         ...,
#         [ 93,  89,  88],
#         [ 90,  84,  84],
#         [ 95,  91,  90]]], dtype=uint8)>

# %%
img = tf.io.read_file(input_img)
#img = tf.image.decode_jpeg(img, channels=3)

# %%
img = tf.image.decode_jpeg(img, channels=3)

# %%
img
# Out:
# <tf.Tensor: id=13, shape=(449, 752, 3), dtype=uint8, numpy=
# array([[[136, 136, 134],
#         [134, 134, 132],
#         [134, 134, 132],
#         ...,
#         [117, 121, 124],
#         [116, 120, 123],
#         [114, 118, 121]],
#
#        [[138, 138, 136],
#         [137, 137, 135],
#         [139, 139, 137],
#         ...,
#         [115, 119, 122],
#         [113, 117, 120],
#         [111, 115, 118]],
#
#        [[141, 141, 141],
#         [142, 142, 142],
#         [144, 144, 144],
#         ...,
#         [112, 116, 117],
#         [108, 112, 113],
#         [106, 110, 111]],
#
#        ...,
#
#        [[119, 120, 115],
#         [117, 118, 113],
#         [114, 115, 110],
#         ...,
#         [ 65,  60,  57],
#         [ 62,  56,  56],
#         [ 62,  57,  54]],
#
#        [[122, 124, 119],
#         [122, 124, 119],
#         [122, 124, 119],
#         ...,
#         [ 82,  77,  74],
#         [ 80,  72,  70],
#         [ 77,  72,  69]],
#
#        [[122, 128, 124],
#         [123, 129, 125],
#         [125, 130, 126],
#         ...,
#         [ 93,  89,  88],
#         [ 90,  84,  84],
#         [ 95,  91,  90]]], dtype=uint8)>

# %% [markdown]
# ## Feature extraction - demonstration

# %%
img_path = '../experiments/rotate/tail+10.jpg'
rgb_img= io.imread(img_path)
plt.imshow(rgb_img, interpolation='nearest');

# %%
hsv_img = rgb2hsv(rgb_img)
value_img = hsv_img[:, :, 2]
fig = plt.figure()
plt.imshow(value_img, cmap='hsv')

# %%
mask_threshold = threshold_li(value_img)
tail_img_mask = value_img < mask_threshold
fig = plt.figure()
plt.imshow(tail_img_mask, cmap='gray')

# %%
contours = measure.find_contours(tail_img_mask, 0.9) 
# Find the largest contour in the list of contours
contours.sort(key=len,reverse=True)
largest_contour = contours[0]

# %%
fig = plt.figure()
plt.imshow(tail_img_mask, cmap='gray')
plt.plot(largest_contour[:, 1], largest_contour[:, 0],  linewidth=3, color = 'red')

# %%
fig = plt.figure()
plt.imshow(rgb_img, interpolation='nearest'); 
plt.plot(largest_contour[:, 1], largest_contour[:, 0],  linewidth=2, color = 'red')

# %%
contour = largest_contour
# Move contour to line towards root (0,0)
contour[:,0] -= contour[:,0].min()
contour[:,1] -= contour[:,1].min()

# Get middle y point of contour line
middle_y = (contour[:,0].max() - contour[:,0].min())/2

# FIND NOTCH POINT
# Get 25% and 75% on x as left and right boundaries to find notch point
left_bound = contour[:,1].max() * 0.25
right_bound = contour[:,1].max() * 0.75

# Cut the area containing notch point by middle_y, left and right boundaries
c_notch = contour[ (contour[:,0] < middle_y) & (contour[:,1] > left_bound) & (contour[:,1] < right_bound)]

# If there is no point in the notch area => bad contour line, returns empty (can't find notch point)
if (len(c_notch) == 0):
    notch_point = []

# Find notch points == points that have the highest y in the notch area
c_notch_y = c_notch[:,0].max()
c_notch_points = c_notch[c_notch[:,0] == c_notch_y]

notch_point = c_notch_points[0]

# FIND LEFT-RIGHT TIPS OF THE FLUKE
# Cut the bottom half of the tail
c_bottom = contour[ (contour[:,0] < middle_y)]
# Find the left tip
left_tip_x = c_bottom[:,1].min()
left_tips = c_bottom[c_bottom[:,1] == left_tip_x]
left_tip = left_tips[0] # if there are several points at min_x
# Find the right tip
right_tip_x = c_bottom[:,1].max()
right_tips = c_bottom[c_bottom[:,1] == right_tip_x]
right_tip = right_tips[-1] # if there are several points at max_x

# %%
fig = plt.figure(figsize=(8,3)) 
#plt.gca().invert_yaxis() # set cordinate root (0,0) to top left point
#plt.plot(notch_point[1], notch_point[0], marker='o', markersize=10, color="red")
#plt.plot(left_tip[1], left_tip[0], marker='o', markersize=10, color="red")
#plt.plot(right_tip[1], right_tip[0], marker='o', markersize=10, color="red")
plt.plot(contour[:, 1], contour[:, 0],  linewidth=2, color = 'black')

# %%
bottom_left = np.array([0,left_tip[1]])
bottom_right = np.array([0,right_tip[1]])
verts = [bottom_left,left_tip, notch_point, right_tip,bottom_right,bottom_left]
codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]
path = Path(verts, codes)

fig, ax = plt.subplots(figsize = [3,6])
patch = patches.PathPatch(path, facecolor='orange', lw=2)
ax.add_patch(patch)
ax.set_xlim(0, notch_point[0]*3)
ax.set_ylim(0, right_tip[1])
ax.plot(contour[:, 0], contour[:, 1],  linewidth=2, color = 'black')  
plt.show()

# %%
path
# Out:
# Path(array([[  0. ,   0. ],
#        [ 33.1,   0. ],
#        [ 98. , 249.1],
#        [103.1, 516.2],
#        [  0. , 516.2],
#        [  0. ,   0. ]]), array([ 1,  2,  2,  2,  2, 79], dtype=uint8))

# %%
c_edge = c_bottom[path.contains_points(c_bottom)]
fig = plt.figure(figsize=(8,3)) 
#plt.gca().invert_yaxis() # set cordinate root (0,0) to top left point
plt.gca().set_aspect('equal', adjustable='box')
plt.plot(notch_point[1], notch_point[0], marker='o', markersize=10, color="red")
plt.plot(left_tip[1], left_tip[0], marker='o', markersize=10, color="red")
plt.plot(right_tip[1], right_tip[0], marker='o', markersize=10, color="red")
plt.plot(c_edge[:, 1], c_edge[:, 0],  linewidth=2, color = 'black')

# %%
diff = right_tip - left_tip
tilt_angle = np.rad2deg(math.atan(diff[0]/diff[1]))
r_img = rotate(c_edge, origin=left_tip, degrees=tilt_angle)

# %%
fig = plt.figure(figsize=(8,3)) 
plt.gca().set_aspect('equal', adjustable='box')
#plt.gca().invert_yaxis() # set cordinate root (0,0) to top left point
plt.plot(c_edge[:, 1], c_edge[:, 0],  linewidth=3, color = 'red')  
#plt.plot((rotate_center[0],points[0][0]), (rotate_center[1],points[0][1]),  linewidth=1, color = 'red')
#plt.plot((rotate_center[0],points[1][0]), (rotate_center[1],points[1][1]),  linewidth=1, color = 'red')
plt.plot(r_img[:, 1], r_img[:, 0],  linewidth=3, color = 'blue')  
#plt.plot((rotate_center[0],new_points[0][0]), (rotate_center[1],new_points[0][1]),  linewidth=1, color = 'blue')
#plt.plot((rotate_center[0],new_points[1][0]), (rotate_center[1],new_points[1][1]),  linewidth=1, color = 'blue')
plt.plot(left_tip[1], left_tip[0], marker='o', markersize=10, color="green")

# %%
fig = plt.figure(figsize=(8,3)) 
plt.gca().set_aspect('equal', adjustable='box')
plt.plot(r_img[:, 1], r_img[:, 0],  linewidth=2, color = 'black')

# %% [markdown]
# ### All in 1

# %%
#img_path = '../experiments/rotate/tail+10.jpg'
#img_path = '../data/test_val/PM-WWA-20170414-359.jpg'
#img_path = '../data/train/1250/PM-WWA-20110820-051.jpg'
#img_path = '../data/test_val/PM-WWA-20170321-322.jpg'
#img_path = '../data/test_val/PM-WWA-20170321-344.jpg'
#img_path = '../data/test_val/PM-WWA-20170321-053.jpg'
img_path = '../data/test_val/PM-WWA-20170430-010.jpg'
rgb_img= io.imread(img_path)
plt.imshow(rgb_img, interpolation='nearest'); 
hsv_img = rgb2hsv(rgb_img)
value_img = hsv_img[:, :, 2]
fig = plt.figure()
plt.imshow(value_img, cmap='hsv')
mask_threshold = threshold_li(value_img)
tail_img_mask = value_img < mask_threshold
fig = plt.figure()
plt.imshow(tail_img_mask, cmap='gray')
contours = measure.find_contours(tail_img_mask, 0.9) 
# Find the largest contour in the list of contours
contours.sort(key=len,reverse=True)
largest_contour = contours[0]
fig = plt.figure()
plt.imshow(tail_img_mask, cmap='gray')
plt.plot(largest_contour[:, 1], largest_contour[:, 0],  linewidth=3, color = 'red') 
fig = plt.figure()
plt.imshow(rgb_img, interpolation='nearest'); 
plt.plot(largest_contour[:, 1], largest_contour[:, 0],  linewidth=2, color = 'red') 
contour = largest_contour
# Move contour to line towards root (0,0)
contour[:,0] -= contour[:,0].min()
contour[:,1] -= contour[:,1].min()

# Get middle y point of contour line
middle_y = (contour[:,0].max() - contour[:,0].min())/2

# FIND NOTCH POINT
# Get 25% and 75% on x as left and right boundaries to find notch point
left_bound = contour[:,1].max() * 0.25
right_bound = contour[:,1].max() * 0.75

# Cut the area containing notch point by middle_y, left and right boundaries
c_notch = contour[ (contour[:,0] < middle_y) & (contour[:,1] > left_bound) & (contour[:,1] < right_bound)]

# If there is no point in the notch area => bad contour line, returns empty (can't find notch point)
if (len(c_notch) == 0):
    notch_point = []

# Find notch points == points that have the highest y in the notch area
c_notch_y = c_notch[:,0].max()
c_notch_points = c_notch[c_notch[:,0] == c_notch_y]

notch_point = c_notch_points[0]

# FIND LEFT-RIGHT TIPS OF THE FLUKE
# Cut the bottom half of the tail
c_bottom = contour[ (contour[:,0] < middle_y)]
# Find the left tip
left_tip_x = c_bottom[:,1].min()
left_tips = c_bottom[c_bottom[:,1] == left_tip_x]
left_tip = left_tips[0] # if there are several points at min_x
# Find the right tip
right_tip_x = c_bottom[:,1].max()
right_tips = c_bottom[c_bottom[:,1] == right_tip_x]
right_tip = right_tips[-1] # if there are several points at max_x
fig = plt.figure(figsize=(8,3)) 
#plt.gca().invert_yaxis() # set cordinate root (0,0) to top left point
plt.plot(notch_point[1], notch_point[0], marker='o', markersize=10, color="red")
plt.plot(left_tip[1], left_tip[0], marker='o', markersize=10, color="red")
plt.plot(right_tip[1], right_tip[0], marker='o', markersize=10, color="red")
plt.plot(contour[:, 1], contour[:, 0],  linewidth=2, color = 'black')  
bottom_left = np.array([0,left_tip[1]])
bottom_right = np.array([0,right_tip[1]])
verts = [bottom_left,left_tip, notch_point, right_tip,bottom_right,bottom_left]
codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]
path = Path(verts, codes)

fig, ax = plt.subplots(figsize = [3,6])
patch = patches.PathPatch(path, facecolor='orange', lw=2)
ax.add_patch(patch)
ax.set_xlim(0, notch_point[0]*3)
ax.set_ylim(0, right_tip[1])
ax.plot(contour[:, 0], contour[:, 1],  linewidth=2, color = 'black')  
plt.show()
c_edge = c_bottom[path.contains_points(c_bottom)]
fig = plt.figure(figsize=(8,3)) 
#plt.gca().invert_yaxis() # set cordinate root (0,0) to top left point
plt.gca().set_aspect('equal', adjustable='box')
plt.plot(notch_point[1], notch_point[0], marker='o', markersize=10, color="red")
plt.plot(left_tip[1], left_tip[0], marker='o', markersize=10, color="red")
plt.plot(right_tip[1], right_tip[0], marker='o', markersize=10, color="red")
plt.plot(c_edge[:, 1], c_edge[:, 0],  linewidth=2, color = 'black')  
diff = right_tip - left_tip
tilt_angle = np.rad2deg(math.atan(diff[0]/diff[1]))
r_img = rotate(c_edge, origin=left_tip, degrees=tilt_angle)
fig = plt.figure(figsize=(8,3)) 
plt.gca().set_aspect('equal', adjustable='box')
#plt.gca().invert_yaxis() # set cordinate root (0,0) to top left point
plt.plot(c_edge[:, 1], c_edge[:, 0],  linewidth=3, color = 'red')  
#plt.plot((rotate_center[0],points[0][0]), (rotate_center[1],points[0][1]),  linewidth=1, color = 'red')
#plt.plot((rotate_center[0],points[1][0]), (rotate_center[1],points[1][1]),  linewidth=1, color = 'red')
plt.plot(r_img[:, 1], r_img[:, 0],  linewidth=3, color = 'blue')  
#plt.plot((rotate_center[0],new_points[0][0]), (rotate_center[1],new_points[0][1]),  linewidth=1, color = 'blue')
#plt.plot((rotate_center[0],new_points[1][0]), (rotate_center[1],new_points[1][1]),  linewidth=1, color = 'blue')
plt.plot(left_tip[1], left_tip[0], marker='o', markersize=10, color="green")
fig = plt.figure(figsize=(8,3)) 
plt.gca().set_aspect('equal', adjustable='box')
plt.plot(r_img[:, 1], r_img[:, 0],  linewidth=2, color = 'black')

# %%
import random
contours = measure.find_contours(tail_img_mask, 0.9) 
# Find the largest contour in the list of contours
contours.sort(key=len,reverse=True)
#largest_contour = contours[0]
fig = plt.figure(figsize=(24,9))
plt.imshow(tail_img_mask, cmap='gray')
for c in contours:
     rgb = (random.random(), random.random(), random.random())
     plt.plot(c[:, 1], c[:, 0],  linewidth=3, color = rgb)

# %% [markdown]
# **LET'S CONTINUE IN Experiment 13**
